# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
pcal = pd.read_csv("length_of_pseudocalanus_females.txt", sep="\t")

# %%
pcal
# Out:
#      DayOfYear  Month  ProsomeLength
# 0           10      1     878.500000
# 1           11      1     980.700000
# 2           12      1     950.000000
# 3           17      1    1016.666667
# 4           17      1     877.500000
# 5           18      1     991.666667
# 6           18      1     940.000000
# 7           19      1     890.800000
# 8           22      1     926.000000
# 9           23      1     915.000000
# 10          29      1     910.666667
# 11          37      2     883.888889
# 12          48      2     837.000000
# 13          48      2    1011.250000
# 14          49      2    1102.000000
# 15          50      2     953.850000
# 16          53      2    1027.130000
# 17          53      2     867.200000
# 18          54      2     925.000000
# 19          58      2    1158.555556
# 20          58      2     916.300000
# 21          60      2     931.555556
# 22          60      2    1016.777778
# 23          62      3    1016.250000
# 24          67      3    1004.300000
# 25          74      3    1062.000000
# 26          76      3     962.666667
# 27          77      3     944.800000
# 28          78      3    1045.750000
# 29          79      3     944.555556
# ..         ...    ...            ...
# 137        268      9     780.500000
# 138        270      9     779.280000
# 139        280     10     724.000000
# 140        281     10     839.300000
# 141        282     10     792.000000
# 142        282     10     714.000000
# 143        290     10     836.000000
# 144        291     10     881.100000
# 145        293     10     901.600000
# 146        293     10     829.660000
# 147        297     10     772.000000
# 148        302     10     829.660000
# 149        313     11     875.333333
# 150        314     11     885.000000
# 151        315     11     760.000000
# 152        315     11     889.000000
# 153        316     11     750.000000
# 154        317     11     900.000000
# 155        318     11     776.000000
# 156        320     11     765.400000
# 157        324     11     854.000000
# 158        330     11     858.333333
# 159        339     12     926.500000
# 160        341     12     922.700000
# 161        344     12     816.000000
# 162        345     12     909.000000
# 163        348     12     891.700000
# 164        350     12     758.000000
# 165        352     12     902.600000
# 166        355     12     871.400000
#
# [167 rows x 3 columns]

# %%
plt.plot(pcal["DayOfYear"], pcal["ProsomeLength"])

# %% [markdown]
# # Exercise 07: Find the mean prosome length by month of the year
#
# 1. Bin the data by month, and compute the mean and standard deviation ($\sigma_{\text{monthly}}$) of the prosome length for each month
# 1. Plot the monthly means with $\pm 1 \times \sigma_{\text{monthly}}$ as the error bar.
# 1. Label axes appropriately, draw gridlines, draw ticks for every month of the year.
